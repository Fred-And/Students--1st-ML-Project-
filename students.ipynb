# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import pickle

# %%
df = pd.read_csv("data/student-mat.csv", sep=";")
df1 = df[["G1","G2","G3","studytime","failures","absences"]]

# %%
# Defining the Label that I want to predict
predict = "G3"

# Separating the X and Y variables for the algorithm
X = np.array(df1.drop([predict], 1 ))
y = np.array(df1[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y, test_size = 0.1)

linear = linear_model.LinearRegression()

linear.fit(x_train, y_train)

acc = linear.score(x_test, y_test)

print(acc)
# Out:
# 0.9143898058568637
# /var/folders/48/jh9djbmj799ffwrgg72_hw680000gn/T/ipykernel_4446/1129980922.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = np.array(df1.drop([predict], 1 ))

# %%
predictions = linear.predict(x_test)

for x in range(len(predictions)):
    print(predictions[x], x_test[x], y_test[x])
# Out:
# 13.97198176488207 [15 14  3  0  2] 15
# 8.803213839412189 [10  9  2  0 10] 10
# 6.8705004058168395 [7 8 4 0 8] 8
# 8.408797563282729 [8 9 2 0 8] 10
# 9.766344138311025 [11 10  2  1 12] 10
# 9.191237579897772 [ 9 10  3  0  4] 10
# 10.038411412262457 [10 10  2  0 17] 10
# 10.98573839672004 [11 11  2  0 12] 11
# 7.647807680261666 [ 9  8  2  1 16] 7
# 7.1050222920706005 [ 8  8  4  0 10] 8
# 11.213636107821284 [11 12  3  1  4] 11
# 10.740174134483231 [11 11  1  0  0] 10
# 10.459270399952738 [13 10  2  1 22] 11
# 15.367073727608036 [16 15  3  0  9] 16
# 12.645870479381445 [12 13  2  0  0] 13
# 14.913661930186931 [14 15  2  0  0] 16
# 12.305799884204465 [14 12  1  0  3] 12
# 5.859931038591915 [ 8  6  2  0 18] 7
# 18.459611521184435 [18 18  3  0  5] 19
# 4.118375945045093 [6 5 2 0 6] 6
# 10.932389694581117 [13 11  2  0  2] 11
# 9.76617279895619 [11 10  1  0  0] 10
# 15.446693801952945 [15 15  2  0 10] 15
# 14.710806972969474 [11 15  1  0  2] 15
# 10.022376458312566 [12 10  2  0  8] 11
# 7.8292125038851434 [10  8  2  0 10] 8
# 10.150121017320913 [12 10  2  1 18] 10
# 8.30250313786836 [10  9  3  0  2] 9
# 9.553332685805044 [10 10  2  0  4] 10
# 9.734254607597476 [ 8 10  1  0 12] 10
# 8.28010682342606 [9 9 1 2 8] 9
# 6.726983707518709 [ 7  7  1  0 14] 5
# 14.988289426564995 [14 15  2  0  2] 15
# 8.259542570526602 [8 9 2 0 4] 10
# 9.511026359649167 [11 10  3  0  4] 11
# 12.55061842995012 [13 13  4  0  4] 12
# 12.67753740841775 [10 13  1  0  4] 14
# 14.828395036689296 [13 15  2  0  2] 16
# 5.198611405832706 [ 6  6  2  2 22] 4
# 8.259542570526602 [8 9 2 0 4] 10
